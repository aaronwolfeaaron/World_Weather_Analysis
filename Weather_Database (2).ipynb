# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Get the nearest city using the citipy module.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Perform an API call with the OpenWeatherMap. Retrieve the following information from the API call: Latitude and longitude, Maximum temperature, Percent humidity, Percent cloudiness, Wind speed, Weather description (for example, clouds, fog, light rain, clear sky).

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    # Parse the JSON and retrieve data.
    city_weather = requests.get(city_url).json()
    # Parse out the needed data.
    try:
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard.
        city_date = city_weather["dt"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})
                          
    except: 
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | varnavino
# Processing Record 2 of Set 1 | saint-philippe
# Processing Record 3 of Set 1 | taburi
# City not found. Skipping...
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | torbay
# Processing Record 6 of Set 1 | narsaq
# Processing Record 7 of Set 1 | bloemfontein
# Processing Record 8 of Set 1 | belmonte
# Processing Record 9 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | guerrero negro
# Processing Record 12 of Set 1 | trat
# Processing Record 13 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 1 | uruzgan
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | minab
# Processing Record 17 of Set 1 | klaksvik
# Processing Record 18 of Set 1 | gornyy
# Processing Record 19 of Set 1 | terrace
# Processing Record 20 of Set 1 | bilma
# Processing Record 21 of Set 1 | ilulissat
# Processing Record 22 of Set 1 | bud
# Processing Record 23 of Set 1 | sinnamary
# Processing Record 24 of Set 1 | flinders
# Processing Record 25 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 26 of Set 1 | east london
# Processing Record 27 of Set 1 | merauke
# Processing Record 28 of Set 1 | porbandar
# Processing Record 29 of Set 1 | solyanka
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | dukat
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | hasaki
# Processing Record 34 of Set 1 | tandalti
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | micheweni
# Processing Record 37 of Set 1 | luderitz
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | williams lake
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | namibe
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | sao filipe
# Processing Record 44 of Set 1 | new norfolk
# Processing Record 45 of Set 1 | dingle
# Processing Record 46 of Set 1 | sibolga
# Processing Record 47 of Set 1 | castro
# Processing Record 48 of Set 1 | henties bay
# Processing Record 49 of Set 1 | grindavik
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | bonthe
# Processing Record 2 of Set 2 | upernavik
# Processing Record 3 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 2 | tuatapere
# Processing Record 5 of Set 2 | iqaluit
# Processing Record 6 of Set 2 | tasiilaq
# Processing Record 7 of Set 2 | codrington
# Processing Record 8 of Set 2 | monrovia
# Processing Record 9 of Set 2 | ponta do sol
# Processing Record 10 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 2 | dikson
# Processing Record 12 of Set 2 | corowa
# Processing Record 13 of Set 2 | khasan
# Processing Record 14 of Set 2 | khelyulya
# Processing Record 15 of Set 2 | chuzhou
# Processing Record 16 of Set 2 | isangel
# Processing Record 17 of Set 2 | awans
# Processing Record 18 of Set 2 | saint george
# Processing Record 19 of Set 2 | la ronge
# Processing Record 20 of Set 2 | rikitea
# Processing Record 21 of Set 2 | punta arenas
# Processing Record 22 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 2 | maniitsoq
# Processing Record 24 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 2 | kavieng
# Processing Record 26 of Set 2 | lorengau
# Processing Record 27 of Set 2 | pimentel
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | carnarvon
# Processing Record 30 of Set 2 | pentecoste
# Processing Record 31 of Set 2 | nanortalik
# Processing Record 32 of Set 2 | caravelas
# Processing Record 33 of Set 2 | georgetown
# Processing Record 34 of Set 2 | souillac
# Processing Record 35 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 36 of Set 2 | kathu
# Processing Record 37 of Set 2 | kinango
# Processing Record 38 of Set 2 | grand-lahou
# Processing Record 39 of Set 2 | chokurdakh
# Processing Record 40 of Set 2 | kingsville
# Processing Record 41 of Set 2 | florian
# Processing Record 42 of Set 2 | kropotkin
# Processing Record 43 of Set 2 | port alfred
# Processing Record 44 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 2 | vitim
# Processing Record 46 of Set 2 | soyo
# Processing Record 47 of Set 2 | chapais
# Processing Record 48 of Set 2 | opuwo
# Processing Record 49 of Set 2 | mandali
# Processing Record 50 of Set 2 | havre-saint-pierre
# Processing Record 1 of Set 3 | butaritari
# Processing Record 2 of Set 3 | sao joao nepomuceno
# Processing Record 3 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 4 of Set 3 | muisne
# Processing Record 5 of Set 3 | tezu
# Processing Record 6 of Set 3 | ormstown
# Processing Record 7 of Set 3 | constitucion
# Processing Record 8 of Set 3 | pitimbu
# Processing Record 9 of Set 3 | razumnoye
# Processing Record 10 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 3 | port elizabeth
# Processing Record 12 of Set 3 | tawnat
# City not found. Skipping...
# Processing Record 13 of Set 3 | talnakh
# Processing Record 14 of Set 3 | rocha
# Processing Record 15 of Set 3 | grand forks
# Processing Record 16 of Set 3 | albany
# Processing Record 17 of Set 3 | ursulo galvan
# Processing Record 18 of Set 3 | kaitangata
# Processing Record 19 of Set 3 | cabo san lucas
# Processing Record 20 of Set 3 | aleksandrovka
# Processing Record 21 of Set 3 | fort nelson
# Processing Record 22 of Set 3 | ardakan
# Processing Record 23 of Set 3 | mnogovershinnyy
# Processing Record 24 of Set 3 | saskylakh
# Processing Record 25 of Set 3 | barrow
# Processing Record 26 of Set 3 | alice springs
# Processing Record 27 of Set 3 | bredasdorp
# Processing Record 28 of Set 3 | fortuna
# Processing Record 29 of Set 3 | ribeira grande
# Processing Record 30 of Set 3 | anadyr
# Processing Record 31 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 32 of Set 3 | pampierstad
# Processing Record 33 of Set 3 | avera
# Processing Record 34 of Set 3 | komsomolskiy
# Processing Record 35 of Set 3 | port shepstone
# Processing Record 36 of Set 3 | barranca
# Processing Record 37 of Set 3 | rundu
# Processing Record 38 of Set 3 | fuerte olimpo
# Processing Record 39 of Set 3 | vieste
# Processing Record 40 of Set 3 | vaini
# Processing Record 41 of Set 3 | karangampel
# Processing Record 42 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 3 | gat
# Processing Record 45 of Set 3 | voh
# Processing Record 46 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 3 | dillon
# Processing Record 48 of Set 3 | riyadh
# Processing Record 49 of Set 3 | avarua
# Processing Record 50 of Set 3 | pahrump
# Processing Record 1 of Set 4 | bluff
# Processing Record 2 of Set 4 | totolapa
# Processing Record 3 of Set 4 | atuona
# Processing Record 4 of Set 4 | puerto madryn
# Processing Record 5 of Set 4 | tomar
# Processing Record 6 of Set 4 | beitbridge
# Processing Record 7 of Set 4 | la libertad
# Processing Record 8 of Set 4 | santa maria
# Processing Record 9 of Set 4 | huaiyin
# Processing Record 10 of Set 4 | kidal
# Processing Record 11 of Set 4 | hambantota
# Processing Record 12 of Set 4 | sambava
# Processing Record 13 of Set 4 | muroto
# Processing Record 14 of Set 4 | lebu
# Processing Record 15 of Set 4 | longyearbyen
# Processing Record 16 of Set 4 | ak-dovurak
# Processing Record 17 of Set 4 | denpasar
# Processing Record 18 of Set 4 | shitanjing
# Processing Record 19 of Set 4 | lichuan
# Processing Record 20 of Set 4 | porto novo
# Processing Record 21 of Set 4 | kodiak
# Processing Record 22 of Set 4 | balakhta
# Processing Record 23 of Set 4 | vilyuysk
# Processing Record 24 of Set 4 | vylkove
# Processing Record 25 of Set 4 | kitgum
# Processing Record 26 of Set 4 | coquimbo
# Processing Record 27 of Set 4 | trincomalee
# Processing Record 28 of Set 4 | khadyzhensk
# Processing Record 29 of Set 4 | touros
# Processing Record 30 of Set 4 | kupang
# Processing Record 31 of Set 4 | airai
# Processing Record 32 of Set 4 | mount gambier
# Processing Record 33 of Set 4 | mar del plata
# Processing Record 34 of Set 4 | koboldo
# City not found. Skipping...
# Processing Record 35 of Set 4 | kahului
# Processing Record 36 of Set 4 | rackeresztur
# Processing Record 37 of Set 4 | nikolskoye
# Processing Record 38 of Set 4 | pevek
# Processing Record 39 of Set 4 | bethel
# Processing Record 40 of Set 4 | chuy
# Processing Record 41 of Set 4 | bubaque
# Processing Record 42 of Set 4 | hovd
# Processing Record 43 of Set 4 | jurado
# Processing Record 44 of Set 4 | faanui
# Processing Record 45 of Set 4 | karratha
# Processing Record 46 of Set 4 | praia
# Processing Record 47 of Set 4 | brae
# Processing Record 48 of Set 4 | marechal deodoro
# Processing Record 49 of Set 4 | tautira
# Processing Record 50 of Set 4 | comodoro rivadavia
# Processing Record 1 of Set 5 | pimenta bueno
# Processing Record 2 of Set 5 | hervey bay
# Processing Record 3 of Set 5 | pisco
# Processing Record 4 of Set 5 | listvyanskiy
# Processing Record 5 of Set 5 | aguas formosas
# Processing Record 6 of Set 5 | batya
# Processing Record 7 of Set 5 | aquiraz
# Processing Record 8 of Set 5 | bilibino
# Processing Record 9 of Set 5 | qaanaaq
# Processing Record 10 of Set 5 | khatanga
# Processing Record 11 of Set 5 | victoria
# Processing Record 12 of Set 5 | hamilton
# Processing Record 13 of Set 5 | te anau
# Processing Record 14 of Set 5 | leer
# Processing Record 15 of Set 5 | matay
# Processing Record 16 of Set 5 | bambanglipuro
# Processing Record 17 of Set 5 | ondjiva
# Processing Record 18 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 19 of Set 5 | bathsheba
# Processing Record 20 of Set 5 | gorontalo
# Processing Record 21 of Set 5 | iquitos
# Processing Record 22 of Set 5 | vanavara
# Processing Record 23 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 5 | ancud
# Processing Record 25 of Set 5 | agirish
# Processing Record 26 of Set 5 | malanje
# Processing Record 27 of Set 5 | paris
# Processing Record 28 of Set 5 | belaya gora
# Processing Record 29 of Set 5 | sorland
# Processing Record 30 of Set 5 | yatou
# Processing Record 31 of Set 5 | ilhabela
# Processing Record 32 of Set 5 | ranong
# Processing Record 33 of Set 5 | krasnoselkup
# Processing Record 34 of Set 5 | cherskiy
# Processing Record 35 of Set 5 | lithakia
# Processing Record 36 of Set 5 | dunedin
# Processing Record 37 of Set 5 | samana
# Processing Record 38 of Set 5 | mecca
# Processing Record 39 of Set 5 | novikovo
# Processing Record 40 of Set 5 | mountain home
# Processing Record 41 of Set 5 | ushtobe
# Processing Record 42 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 43 of Set 5 | hilo
# Processing Record 44 of Set 5 | arraial do cabo
# Processing Record 45 of Set 5 | high level
# Processing Record 46 of Set 5 | masterton
# Processing Record 47 of Set 5 | tuktoyaktuk
# Processing Record 48 of Set 5 | viedma
# Processing Record 49 of Set 5 | trabzon
# Processing Record 50 of Set 5 | trairi
# Processing Record 1 of Set 6 | fortuna foothills
# Processing Record 2 of Set 6 | santiago
# Processing Record 3 of Set 6 | ambon
# Processing Record 4 of Set 6 | tevaitoa
# Processing Record 5 of Set 6 | sursk
# Processing Record 6 of Set 6 | labuan
# Processing Record 7 of Set 6 | dambulla
# Processing Record 8 of Set 6 | erenhot
# Processing Record 9 of Set 6 | coihaique
# Processing Record 10 of Set 6 | kefamenanu
# Processing Record 11 of Set 6 | mahebourg
# Processing Record 12 of Set 6 | renfrew
# Processing Record 13 of Set 6 | lancaster
# Processing Record 14 of Set 6 | alihe
# Processing Record 15 of Set 6 | san jose
# Processing Record 16 of Set 6 | maraa
# Processing Record 17 of Set 6 | pochutla
# Processing Record 18 of Set 6 | salinopolis
# Processing Record 19 of Set 6 | egvekinot
# Processing Record 20 of Set 6 | kentau
# Processing Record 21 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 6 | stamsund
# City not found. Skipping...
# Processing Record 23 of Set 6 | komatipoort
# Processing Record 24 of Set 6 | mogadishu
# Processing Record 25 of Set 6 | ust-koksa
# Processing Record 26 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 6 | thunder bay
# Processing Record 28 of Set 6 | sisimiut
# Processing Record 29 of Set 6 | hithadhoo
# Processing Record 30 of Set 6 | ambanja
# Processing Record 31 of Set 6 | havoysund
# Processing Record 32 of Set 6 | armacao dos buzios
# City not found. Skipping...
# Processing Record 33 of Set 6 | ilmajoki
# Processing Record 34 of Set 6 | qaqortoq
# Processing Record 35 of Set 6 | norman wells
# Processing Record 36 of Set 6 | westport
# Processing Record 37 of Set 6 | nhulunbuy
# Processing Record 38 of Set 6 | srednekolymsk
# Processing Record 39 of Set 6 | kununurra
# Processing Record 40 of Set 6 | deputatskiy
# Processing Record 41 of Set 6 | gizo
# Processing Record 42 of Set 6 | san quintin
# Processing Record 43 of Set 6 | yangcun
# Processing Record 44 of Set 6 | naryan-mar
# Processing Record 45 of Set 6 | tura
# Processing Record 46 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 6 | bairiki
# Processing Record 48 of Set 6 | korla
# Processing Record 49 of Set 6 | lasa
# Processing Record 50 of Set 6 | mokhsogollokh
# Processing Record 1 of Set 7 | orda
# Processing Record 2 of Set 7 | broken hill
# Processing Record 3 of Set 7 | bereda
# Processing Record 4 of Set 7 | antofagasta
# Processing Record 5 of Set 7 | tiksi
# Processing Record 6 of Set 7 | makakilo city
# Processing Record 7 of Set 7 | norfolk
# Processing Record 8 of Set 7 | bac lieu
# Processing Record 9 of Set 7 | canutama
# Processing Record 10 of Set 7 | kindu
# Processing Record 11 of Set 7 | zyryanskoye
# Processing Record 12 of Set 7 | san vicente
# Processing Record 13 of Set 7 | azrow
# City not found. Skipping...
# Processing Record 14 of Set 7 | barao de melgaco
# Processing Record 15 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 7 | nemuro
# Processing Record 17 of Set 7 | la palma
# Processing Record 18 of Set 7 | ahipara
# Processing Record 19 of Set 7 | boa vista
# Processing Record 20 of Set 7 | kandrian
# Processing Record 21 of Set 7 | port hawkesbury
# Processing Record 22 of Set 7 | sabha
# Processing Record 23 of Set 7 | nuuk
# Processing Record 24 of Set 7 | totolapan
# Processing Record 25 of Set 7 | mayumba
# Processing Record 26 of Set 7 | kuvandyk
# Processing Record 27 of Set 7 | dekar
# Processing Record 28 of Set 7 | vila
# Processing Record 29 of Set 7 | vila franca do campo
# Processing Record 30 of Set 7 | huangnihe
# Processing Record 31 of Set 7 | chiredzi
# Processing Record 32 of Set 7 | palencia
# Processing Record 33 of Set 7 | rapid valley
# Processing Record 34 of Set 7 | myitkyina
# Processing Record 35 of Set 7 | zhigansk
# Processing Record 36 of Set 7 | mount darwin
# Processing Record 37 of Set 7 | grenaa
# Processing Record 38 of Set 7 | emerald
# Processing Record 39 of Set 7 | san patricio
# Processing Record 40 of Set 7 | platnirovskaya
# Processing Record 41 of Set 7 | magadan
# Processing Record 42 of Set 7 | aklavik
# Processing Record 43 of Set 7 | hazorasp
# Processing Record 44 of Set 7 | kasongo-lunda
# Processing Record 45 of Set 7 | pauini
# Processing Record 46 of Set 7 | shaoyang
# Processing Record 47 of Set 7 | atkinson
# Processing Record 48 of Set 7 | sergeyevka
# Processing Record 49 of Set 7 | jhalida
# Processing Record 50 of Set 7 | kaka
# Processing Record 1 of Set 8 | sitka
# Processing Record 2 of Set 8 | dicabisagan
# Processing Record 3 of Set 8 | kuching
# Processing Record 4 of Set 8 | severo-kurilsk
# Processing Record 5 of Set 8 | bani
# Processing Record 6 of Set 8 | vila velha
# Processing Record 7 of Set 8 | richards bay
# Processing Record 8 of Set 8 | chara
# Processing Record 9 of Set 8 | coruripe
# Processing Record 10 of Set 8 | los llanos de aridane
# Processing Record 11 of Set 8 | chhatarpur
# Processing Record 12 of Set 8 | chauk
# Processing Record 13 of Set 8 | saldanha
# Processing Record 14 of Set 8 | khash
# Processing Record 15 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 8 | vardo
# Processing Record 17 of Set 8 | chapleau
# Processing Record 18 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 19 of Set 8 | port arthur
# Processing Record 20 of Set 8 | barcelona
# Processing Record 21 of Set 8 | pangnirtung
# Processing Record 22 of Set 8 | alyangula
# Processing Record 23 of Set 8 | bengkulu
# Processing Record 24 of Set 8 | haines junction
# Processing Record 25 of Set 8 | katsuura
# Processing Record 26 of Set 8 | poum
# Processing Record 27 of Set 8 | leningradskiy
# Processing Record 28 of Set 8 | wajir
# Processing Record 29 of Set 8 | sur
# Processing Record 30 of Set 8 | flin flon
# Processing Record 31 of Set 8 | thabazimbi
# Processing Record 32 of Set 8 | lagoa
# Processing Record 33 of Set 8 | ponta delgada
# Processing Record 34 of Set 8 | kaarina
# Processing Record 35 of Set 8 | northam
# Processing Record 36 of Set 8 | yaounde
# Processing Record 37 of Set 8 | rorvik
# Processing Record 38 of Set 8 | thayetmyo
# Processing Record 39 of Set 8 | lakatoro
# Processing Record 40 of Set 8 | paoua
# Processing Record 41 of Set 8 | muzhi
# Processing Record 42 of Set 8 | kuytun
# Processing Record 43 of Set 8 | tokamachi
# Processing Record 44 of Set 8 | uglich
# Processing Record 45 of Set 8 | kimbe
# Processing Record 46 of Set 8 | freeport
# Processing Record 47 of Set 8 | pyatnitskoye
# Processing Record 48 of Set 8 | muros
# Processing Record 49 of Set 8 | puerto carreno
# Processing Record 50 of Set 8 | clyde river
# Processing Record 1 of Set 9 | kadoma
# Processing Record 2 of Set 9 | chippewa falls
# Processing Record 3 of Set 9 | khorixas
# Processing Record 4 of Set 9 | oranjemund
# Processing Record 5 of Set 9 | la tuque
# Processing Record 6 of Set 9 | dakar
# Processing Record 7 of Set 9 | hofn
# Processing Record 8 of Set 9 | isla mujeres
# Processing Record 9 of Set 9 | rwamagana
# Processing Record 10 of Set 9 | noumea
# Processing Record 11 of Set 9 | russell
# Processing Record 12 of Set 9 | daru
# Processing Record 13 of Set 9 | nancha
# Processing Record 14 of Set 9 | capitan bado
# Processing Record 15 of Set 9 | lhokseumawe
# Processing Record 16 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 17 of Set 9 | acapulco
# Processing Record 18 of Set 9 | kovdor
# Processing Record 19 of Set 9 | abu kamal
# Processing Record 20 of Set 9 | tessalit
# Processing Record 21 of Set 9 | tanda
# Processing Record 22 of Set 9 | canete
# Processing Record 23 of Set 9 | khandyga
# Processing Record 24 of Set 9 | khani
# Processing Record 25 of Set 9 | rawson
# Processing Record 26 of Set 9 | sao felix do xingu
# Processing Record 27 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 28 of Set 9 | port hardy
# Processing Record 29 of Set 9 | solaro
# Processing Record 30 of Set 9 | thompson
# Processing Record 31 of Set 9 | jiroft
# City not found. Skipping...
# Processing Record 32 of Set 9 | portland
# Processing Record 33 of Set 9 | kiama
# Processing Record 34 of Set 9 | naze
# Processing Record 35 of Set 9 | guadix
# Processing Record 36 of Set 9 | panaba
# Processing Record 37 of Set 9 | general jose eduvigis diaz
# Processing Record 38 of Set 9 | campo verde
# Processing Record 39 of Set 9 | entebbe
# Processing Record 40 of Set 9 | panguna
# Processing Record 41 of Set 9 | mugumu
# Processing Record 42 of Set 9 | verkhniy lomov
# Processing Record 43 of Set 9 | port lincoln
# Processing Record 44 of Set 9 | mwinilunga
# Processing Record 45 of Set 9 | cidreira
# Processing Record 46 of Set 9 | aykhal
# Processing Record 47 of Set 9 | provideniya
# Processing Record 48 of Set 9 | general roca
# Processing Record 49 of Set 9 | tolaga bay
# Processing Record 50 of Set 9 | solnechnyy
# Processing Record 1 of Set 10 | healdsburg
# Processing Record 2 of Set 10 | mentor
# Processing Record 3 of Set 10 | kytmanovo
# Processing Record 4 of Set 10 | tungor
# Processing Record 5 of Set 10 | makokou
# Processing Record 6 of Set 10 | axim
# Processing Record 7 of Set 10 | chok chai
# Processing Record 8 of Set 10 | makat
# Processing Record 9 of Set 10 | aktau
# Processing Record 10 of Set 10 | mareeba
# Processing Record 11 of Set 10 | somerville
# Processing Record 12 of Set 10 | chingola
# Processing Record 13 of Set 10 | ambilobe
# Processing Record 14 of Set 10 | corrente
# Processing Record 15 of Set 10 | goderich
# Processing Record 16 of Set 10 | vawkavysk
# Processing Record 17 of Set 10 | carutapera
# Processing Record 18 of Set 10 | novyy urengoy
# Processing Record 19 of Set 10 | zaterechnyy
# Processing Record 20 of Set 10 | rio grande
# Processing Record 21 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 22 of Set 10 | mizdah
# Processing Record 23 of Set 10 | mae sai
# Processing Record 24 of Set 10 | kodinsk
# Processing Record 25 of Set 10 | esperance
# Processing Record 26 of Set 10 | morant bay
# Processing Record 27 of Set 10 | santa rosalia
# Processing Record 28 of Set 10 | woodward
# Processing Record 29 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 30 of Set 10 | iskateley
# Processing Record 31 of Set 10 | estelle
# Processing Record 32 of Set 10 | luebo
# Processing Record 33 of Set 10 | port macquarie
# Processing Record 34 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 35 of Set 10 | curup
# Processing Record 36 of Set 10 | cayenne
# Processing Record 37 of Set 10 | inhambane
# Processing Record 38 of Set 10 | menongue
# Processing Record 39 of Set 10 | saint-francois
# Processing Record 40 of Set 10 | machiques
# Processing Record 41 of Set 10 | mehamn
# Processing Record 42 of Set 10 | gilgit
# Processing Record 43 of Set 10 | majene
# Processing Record 44 of Set 10 | anloga
# Processing Record 45 of Set 10 | jeremie
# Processing Record 46 of Set 10 | berlevag
# Processing Record 47 of Set 10 | bagdarin
# Processing Record 48 of Set 10 | nioro
# Processing Record 49 of Set 10 | roebourne
# Processing Record 50 of Set 10 | dabat
# Processing Record 1 of Set 11 | victor harbor
# Processing Record 2 of Set 11 | barabai
# Processing Record 3 of Set 11 | latung
# Processing Record 4 of Set 11 | mgandu
# Processing Record 5 of Set 11 | bowen
# Processing Record 6 of Set 11 | przhevalskoye
# Processing Record 7 of Set 11 | shelburne
# Processing Record 8 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 11 | lexington
# Processing Record 10 of Set 11 | krasnorechenskiy
# Processing Record 11 of Set 11 | jansath
# Processing Record 12 of Set 11 | manta
# Processing Record 13 of Set 11 | salalah
# Processing Record 14 of Set 11 | buala
# Processing Record 15 of Set 11 | sao joao da barra
# Processing Record 16 of Set 11 | vaitape
# Processing Record 17 of Set 11 | pangai
# Processing Record 18 of Set 11 | tilichiki
# Processing Record 19 of Set 11 | padang
# Processing Record 20 of Set 11 | telgte
# Processing Record 21 of Set 11 | port lavaca
# Processing Record 22 of Set 11 | gari
# Processing Record 23 of Set 11 | mount isa
# Processing Record 24 of Set 11 | nueve de julio
# Processing Record 25 of Set 11 | abay
# Processing Record 26 of Set 11 | kharitonovo
# Processing Record 27 of Set 11 | porto belo
# Processing Record 28 of Set 11 | bima
# Processing Record 29 of Set 11 | oistins
# Processing Record 30 of Set 11 | buynaksk
# Processing Record 31 of Set 11 | saint-leu
# Processing Record 32 of Set 11 | illapel
# Processing Record 33 of Set 11 | hami
# Processing Record 34 of Set 11 | luanda
# Processing Record 35 of Set 11 | atambua
# Processing Record 36 of Set 11 | cockburn town
# Processing Record 37 of Set 11 | faya
# Processing Record 38 of Set 11 | manzhouli
# Processing Record 39 of Set 11 | kokstad
# Processing Record 40 of Set 11 | jupiter
# Processing Record 41 of Set 11 | jiwani
# Processing Record 42 of Set 11 | conde
# Processing Record 43 of Set 11 | khovu-aksy
# Processing Record 44 of Set 11 | campbellton
# Processing Record 45 of Set 11 | nevelsk
# Processing Record 46 of Set 11 | husavik
# Processing Record 47 of Set 11 | vicuna
# Processing Record 48 of Set 11 | shingu
# Processing Record 49 of Set 11 | keti bandar
# Processing Record 50 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 12 | cabedelo
# Processing Record 3 of Set 12 | marzuq
# Processing Record 4 of Set 12 | sistranda
# Processing Record 5 of Set 12 | kargasok
# Processing Record 6 of Set 12 | hobyo
# Processing Record 7 of Set 12 | goure
# Processing Record 8 of Set 12 | twentynine palms
# Processing Record 9 of Set 12 | saint-georges
# Processing Record 10 of Set 12 | minsk
# Processing Record 11 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 12 of Set 12 | lulea
# Processing Record 13 of Set 12 | whitehorse
# Processing Record 14 of Set 12 | pedernales
# Processing Record 15 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record 16 of Set 12 | port-gentil
# Processing Record 17 of Set 12 | north kessock
# Processing Record 18 of Set 12 | jerantut
# Processing Record 19 of Set 12 | kuminskiy
# Processing Record 20 of Set 12 | najran
# Processing Record 21 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 12 | vestmannaeyjar
# Processing Record 24 of Set 12 | hammerfest
# Processing Record 25 of Set 12 | bandarbeyla
# Processing Record 26 of Set 12 | zhoucheng
# Processing Record 27 of Set 12 | gonaives
# Processing Record 28 of Set 12 | tecoanapa
# Processing Record 29 of Set 12 | hearst
# Processing Record 30 of Set 12 | abalak
# Processing Record 31 of Set 12 | namatanai
# Processing Record 32 of Set 12 | leshukonskoye
# Processing Record 33 of Set 12 | piacabucu
# Processing Record 34 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 35 of Set 12 | camacha
# Processing Record 36 of Set 12 | cururupu
# Processing Record 37 of Set 12 | sri aman
# Processing Record 38 of Set 12 | tabuk
# Processing Record 39 of Set 12 | oranjestad
# Processing Record 40 of Set 12 | sao tome
# Processing Record 41 of Set 12 | marataizes
# Processing Record 42 of Set 12 | chumphon
# Processing Record 43 of Set 12 | puerto del rosario
# Processing Record 44 of Set 12 | san policarpo
# Processing Record 45 of Set 12 | dongsheng
# Processing Record 46 of Set 12 | san juan bautista
# Processing Record 47 of Set 12 | san vicente de canete
# Processing Record 48 of Set 12 | geraldton
# Processing Record 49 of Set 12 | vyazma
# Processing Record 50 of Set 12 | antsla
# Processing Record 1 of Set 13 | beira
# Processing Record 2 of Set 13 | necochea
# Processing Record 3 of Set 13 | taunsa
# Processing Record 4 of Set 13 | tomatlan
# Processing Record 5 of Set 13 | orotukan
# Processing Record 6 of Set 13 | beringovskiy
# Processing Record 7 of Set 13 | thinadhoo
# Processing Record 8 of Set 13 | kurilsk
# Processing Record 9 of Set 13 | maldonado
# Processing Record 10 of Set 13 | domoni
# Processing Record 11 of Set 13 | amnat charoen
# Processing Record 12 of Set 13 | ulladulla
# Processing Record 13 of Set 13 | nizhnyaya omka
# Processing Record 14 of Set 13 | marawi
# Processing Record 15 of Set 13 | edd
# Processing Record 16 of Set 13 | keita
# Processing Record 17 of Set 13 | nome
# Processing Record 18 of Set 13 | santa isabel
# Processing Record 19 of Set 13 | dong hoi
# Processing Record 20 of Set 13 | burkhala
# City not found. Skipping...
# Processing Record 21 of Set 13 | mallaig
# Processing Record 22 of Set 13 | mariveles
# Processing Record 23 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 13 | pitogo
# Processing Record 26 of Set 13 | zephyrhills
# Processing Record 27 of Set 13 | ambah
# Processing Record 28 of Set 13 | harriston
# Processing Record 29 of Set 13 | aksu
# Processing Record 30 of Set 13 | ishigaki
# Processing Record 31 of Set 13 | seydi
# Processing Record 32 of Set 13 | tete
# Processing Record 33 of Set 13 | lisala
# Processing Record 34 of Set 13 | kotovo
# Processing Record 35 of Set 13 | soro
# Processing Record 36 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 37 of Set 13 | srandakan
# Processing Record 38 of Set 13 | maceio
# Processing Record 39 of Set 13 | miramar
# Processing Record 40 of Set 13 | la gaulette
# City not found. Skipping...
# Processing Record 41 of Set 13 | antequera
# Processing Record 42 of Set 13 | beloha
# Processing Record 43 of Set 13 | lata
# Processing Record 44 of Set 13 | tucdao
# Processing Record 45 of Set 13 | dagana
# Processing Record 46 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 13 | tongren
# Processing Record 48 of Set 13 | finca cincuenta y uno
# City not found. Skipping...
# Processing Record 49 of Set 13 | conceicao do araguaia
# Processing Record 50 of Set 13 | xacmaz
# Processing Record 1 of Set 14 | the valley
# Processing Record 2 of Set 14 | satis
# Processing Record 3 of Set 14 | kendari
# Processing Record 4 of Set 14 | lake havasu city
# Processing Record 5 of Set 14 | alofi
# Processing Record 6 of Set 14 | mudyuga
# City not found. Skipping...
# Processing Record 7 of Set 14 | kedgwick
# Processing Record 8 of Set 14 | laramie
# Processing Record 9 of Set 14 | raudeberg
# Processing Record 10 of Set 14 | kushiro
# Processing Record 11 of Set 14 | wilmington
# Processing Record 12 of Set 14 | reforma
# Processing Record 13 of Set 14 | novoagansk
# Processing Record 14 of Set 14 | ust-nera
# Processing Record 15 of Set 14 | ankara
# Processing Record 16 of Set 14 | petrivka
# Processing Record 17 of Set 14 | half moon bay
# Processing Record 18 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 14 | laguna
# Processing Record 20 of Set 14 | preeceville
# Processing Record 21 of Set 14 | ornskoldsvik
# Processing Record 22 of Set 14 | bansi
# Processing Record 23 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 25 of Set 14 | dawlatabad
# Processing Record 26 of Set 14 | wysokie mazowieckie
# Processing Record 27 of Set 14 | upington
# Processing Record 28 of Set 14 | virginia beach
# Processing Record 29 of Set 14 | jarjis
# City not found. Skipping...
# Processing Record 30 of Set 14 | aksay
# Processing Record 31 of Set 14 | college
# Processing Record 32 of Set 14 | guarapari
# Processing Record 33 of Set 14 | lavrentiya
# Processing Record 34 of Set 14 | bacolod
# Processing Record 35 of Set 14 | tarancon
# Processing Record 36 of Set 14 | mananjary
# Processing Record 37 of Set 14 | waingapu
# Processing Record 38 of Set 14 | bajo baudo
# City not found. Skipping...
# Processing Record 39 of Set 14 | maarianhamina
# Processing Record 40 of Set 14 | hemnesberget
# Processing Record 41 of Set 14 | san miguel
# Processing Record 42 of Set 14 | zuwarah
# Processing Record 43 of Set 14 | pedro betancourt
# Processing Record 44 of Set 14 | quesnel
# Processing Record 45 of Set 14 | sakakah
# Processing Record 46 of Set 14 | eyl
# Processing Record 47 of Set 14 | baykit
# Processing Record 48 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 14 | quatre cocos
# Processing Record 50 of Set 14 | almonte
# Processing Record 1 of Set 15 | oksfjord
# Processing Record 2 of Set 15 | kruisfontein
# Processing Record 3 of Set 15 | lisakovsk
# Processing Record 4 of Set 15 | puerto quijarro
# Processing Record 5 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 6 of Set 15 | dhanbad
# Processing Record 7 of Set 15 | walvis bay
# Processing Record 8 of Set 15 | fairbanks
# Processing Record 9 of Set 15 | kavaratti
# Processing Record 10 of Set 15 | angra
# City not found. Skipping...
# Processing Record 11 of Set 15 | harper
# Processing Record 12 of Set 15 | kulhudhuffushi
# Processing Record 13 of Set 15 | mkushi
# Processing Record 14 of Set 15 | selfoss
# Processing Record 15 of Set 15 | macapa
# Processing Record 16 of Set 15 | kyabe
# Processing Record 17 of Set 15 | gambela
# Processing Record 18 of Set 15 | usak
# Processing Record 19 of Set 15 | assare
# Processing Record 20 of Set 15 | svetlyy
# Processing Record 21 of Set 15 | roald
# Processing Record 22 of Set 15 | san cristobal
# Processing Record 23 of Set 15 | mawlaik
# Processing Record 24 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 15 | mandal
# Processing Record 27 of Set 15 | zima
# Processing Record 28 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 29 of Set 15 | yumen
# Processing Record 30 of Set 15 | zhuhai
# Processing Record 31 of Set 15 | krasnaya gora
# Processing Record 32 of Set 15 | tigil
# Processing Record 33 of Set 15 | guangyuan
# Processing Record 34 of Set 15 | petit goave
# Processing Record 35 of Set 15 | vostok
# Processing Record 36 of Set 15 | shibetsu
# Processing Record 37 of Set 15 | dubuque
# Processing Record 38 of Set 15 | yenagoa
# Processing Record 39 of Set 15 | abu samrah
# Processing Record 40 of Set 15 | nigran
# Processing Record 41 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 42 of Set 15 | lompoc
# Processing Record 43 of Set 15 | kokopo
# Processing Record 44 of Set 15 | yebaishou
# Processing Record 45 of Set 15 | vryheid
# Processing Record 46 of Set 15 | taltal
# Processing Record 47 of Set 15 | pontian kecil
# Processing Record 48 of Set 15 | acarau
# Processing Record 49 of Set 15 | supe
# Processing Record 50 of Set 15 | nogliki
# Processing Record 1 of Set 16 | yar-sale
# Processing Record 2 of Set 16 | burla
# Processing Record 3 of Set 16 | ypane
# Processing Record 4 of Set 16 | damietta
# Processing Record 5 of Set 16 | yerbogachen
# Processing Record 6 of Set 16 | dhidhdhoo
# Processing Record 7 of Set 16 | xining
# Processing Record 8 of Set 16 | atar
# Processing Record 9 of Set 16 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 16 | qostanay
# Processing Record 11 of Set 16 | assiniboia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Varnavino  57.4035   45.0916      4.26        98          70
# 1  Saint-Philippe -21.3585   55.7679     80.19        85          93
# 2        Hermanus -34.4187   19.2345     63.90        68          98
# 3          Torbay  47.6666  -52.7314     41.29        95         100
# 4          Narsaq  60.9167  -46.0500     25.02        71         100
# 5    Bloemfontein -29.1211   26.2140     67.48        83           5
# 6        Belmonte -15.8631  -38.8828     81.10        77          91
# 7  Guerrero Negro  27.9769 -114.0611     67.46        67          97
# 8            Trat  12.5000  102.5000     81.99        59          96
# 9         Uruzgan  32.8333   66.0000     43.68        92         100
#
#    Wind Speed Country        Date   Current Description
# 0        4.97      RU  1642543797         broken clouds
# 1        3.47      RE  1642543237            light rain
# 2        9.60      ZA  1642543233       overcast clouds
# 3        5.01      CA  1642543292  heavy intensity rain
# 4       12.93      GL  1642543294                  snow
# 5       11.50      ZA  1642543797             clear sky
# 6        6.55      BR  1642543373       overcast clouds
# 7       13.04      MX  1642543653       overcast clouds
# 8        3.94      TH  1642543798       overcast clouds
# 9        1.36      AF  1642543799       overcast clouds

# %%
# Reorder the columns.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Varnavino      RU  57.4035   45.0916      4.26        98          70
# 1  Saint-Philippe      RE -21.3585   55.7679     80.19        85          93
# 2        Hermanus      ZA -34.4187   19.2345     63.90        68          98
# 3          Torbay      CA  47.6666  -52.7314     41.29        95         100
# 4          Narsaq      GL  60.9167  -46.0500     25.02        71         100
# 5    Bloemfontein      ZA -29.1211   26.2140     67.48        83           5
# 6        Belmonte      BR -15.8631  -38.8828     81.10        77          91
# 7  Guerrero Negro      MX  27.9769 -114.0611     67.46        67          97
# 8            Trat      TH  12.5000  102.5000     81.99        59          96
# 9         Uruzgan      AF  32.8333   66.0000     43.68        92         100
#
#    Wind Speed   Current Description
# 0        4.97         broken clouds
# 1        3.47            light rain
# 2        9.60       overcast clouds
# 3        5.01  heavy intensity rain
# 4       12.93                  snow
# 5       11.50             clear sky
# 6        6.55       overcast clouds
# 7       13.04       overcast clouds
# 8        3.94       overcast clouds
# 9        1.36       overcast clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
# Create the output file (CSV).

city_data_df.to_csv('WeatherPy_Database.csv')
